# %% [markdown]
# <a href="https://colab.research.google.com/github/oerv13-gh/Ibero/blob/main/Manejo_Diccionario.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
User1 = {
    "Nombre" : "Julian",
    "Apellido" : "Londoño",
    "Edad" : "43",
    "Direcion" : "Calle 3",
    "Materias" :  ["Math", "Sciencie", "Social" ]
    }

User2 = {
    "Nombre" : "Camilo",
    "Apellido" : "Melo",
    "Edad" : "25",
    "Direcion" : "Calle 93",
    "Materias" :  ["Math", "Sciencie", "Languaje" ]
    }

# %%
print(User2)
# Out:
# {'Nombre': 'Wilmer', 'Apellido': 'Melo', 'Edad': '25', 'Direcion': 'Calle 93', 'Materias': ['Math', 'Sciencie', 'Languaje'], 'Salario': '3000'}

# %%
print(User2["Nombre" ])
# Out:
# Wilmer

# %%
# Actualizar dato
User2["Nombre"] = "Wilmer"

# %%
# Añadir campo al Diccionario
User2["Salario"] = "3000"

# %%
# Ver las llaves
print(User1.keys())
# Out:
# dict_keys(['Nombre', 'Apellido', 'Edad', 'Direcion', 'Materias'])

# %%
# Acceder a los valores
print(User1.values())
# Out:
# dict_values(['Julian', 'Londoño', '43', 'Calle 3', ['Math', 'Sciencie', 'Social']])

# %%
# Recorrido de valores
for valor in User1.values():
    print(valor)
# Out:
# Julian
# Londoño
# 43
# Calle 3
# ['Math', 'Sciencie', 'Social']

# %%
# Recorrido de valores asignacion a lista
mi_lsita = []
for valor in User1.values():
    print(valor)
    mi_lsita.append(valor)
# Out:
# Julian
# Londoño
# 43
# Calle 3
# ['Math', 'Sciencie', 'Social']

# %%
print(mi_lsita)
# Out:
# ['Julian', 'Londoño', '43', 'Calle 3', ['Math', 'Sciencie', 'Social']]
